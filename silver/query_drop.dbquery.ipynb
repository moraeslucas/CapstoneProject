-- %%
ALTER TABLE workspace.sc_silver.bd_rede_hyundai 
--Enable column mapping for DROP support
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.bd_rede_hyundai 
DROP COLUMN IF EXISTS billing_client_nav_description,
											sales_area_manager_code,
											sales_area_manager_value,
											row_names,
											aftersales_performance_grouping_dt_changed,
											modified_time,
											last_activity_time,
											sales_area_manager_dt_changed,
											aftersales_area_manager_code,
											aftersales_area_manager_dt_changed,
											sales_team_code,
											aftersales_team_code,
											sales_team_dt_changed,
											billing_client_nav_code,
											aftersales_team_dt_changed,
											billing_client_nav_value,
											nif_grouping_code,
											nif_grouping_value,
											nif_grouping_dt_changed,
											nif,
											billing_client_nav_dt_changed,
											dealer_contract_code,
											sales_performance_grouping_code,
											dealer_contract_dt_changed,
											aftersales_performance_grouping_code,
											sales_performance_grouping_dt_changed,
											cp3,
											cp4,
											client_group_code,
											client_group_dt_changed,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.campaigns 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.campaigns
DROP COLUMN IF EXISTS data,
											row_names,
											start_date,
											end_date,
											modified_time,
											tag,
											modelo,
											oferta,
											modelo_,
											actual_cost,
											budgeted_cost,
											expected_response,
											expected_revenue,
											numbers_sent,
											status,
											type,
											description,
											account_id,
											budget_rebalance_flag,
											buying_type,
											effective_status,
											lead_source,
											objective,
											start_time,
											stop_time,
											updated_time,
											use_spend_cap,
											layout,
											campaign_subject,
											reply_to_address,
											sender_address,
											sender_name,
											of,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.campanhas_tecnicas 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.campanhas_tecnicas
DROP COLUMN IF EXISTS tsb, 
                      tsb_url1,
											email,
											unsubscribed_mode,
											tag,
											unsubscribed_time,
											secondary_email,		
											last_activity_time,
											modified_time,
											row_names,
											_fivetran_index,
											campanha_tecnica_owner_name,
											atualizarlink,
											ckd_plant,
											email_opt_out,
											visiting_owner,
											odometer_type;


ALTER TABLE workspace.sc_silver.contactos_importador_pbs 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.contactos_importador_pbs
DROP COLUMN IF EXISTS matricula,
											modo_de_contacto_preferencial,
											numero_de_cliente_dms,
											quando_prefere_ser_contactado,
											quando_necessita_carro_novo,
											motivo_de_interesse,
											concessao_preferida_myhyundai,
											concessao,
											did_you_mean,
											zipcode,
											city,
											chave_instalacao_bd_rede,
											instalacao,
											ticket_suporte,
											tag,
											region,
											country,
											pioneiros_myhyundai,
											chave_concessao_bd_rede,
											equipa,
											formulario,
											concelho,
											gender,
											firstname,
											lastname,
											data_de_nascimento,
											distrito,
											ativacao_conta_myhyundai,
											origem_registo,
											sexo,
											data_de_validade_de_consentimento_hyundai,
											link_centro_consentimento,
											consentimento,
											data_de_recolha_de_consentimento_hyundai,
											pais,
											email_opt_out,
											check,
											free_email,
											mx_found,
											mx_founds,
											rgdp_art_17,
											smtp_provider,
											status,
											estado_email,
											account,
											rgpd_art__17,
											row_names,
											apelido,
											contacto_importador_owner_name,
											email,
											secondary_email,
											last_activity_time,
											modified_time,
											telemovel,
											telefone,
											nif,
											morada,
											codigo_postal,
											localidade,
											login_myhyundai,
											cctemp,
											atualizacao_cc_manual,
											nao_atualizar_concessao,
											ultimo_login,
											unsubscribed_mode,
											unsubscribed_time,
											domain,
											domain_age_days,
											enviar_sms,
											_fivetran_index,
											sub_status,
											smptp_provider,
											rgpd_art_17,
											mx_record,
											tipo_de_pedido,
											genero,
											age;


ALTER TABLE workspace.sc_silver.contactos_pbs 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.contactos_pbs
DROP COLUMN IF EXISTS conta_name,
											secondary_email,
											matricula,
											id_conta,
											numero_de_cliente_dms,
											quando_prefere_ser_contactado,
											quando_necessita_carro_novo,
											motivo_de_interesse,
											data_criacao_do_contacto,
											profissao,
											classificacao_do_contacto,
											last_name,
											email,
											mobile,
											first_name,
											phone,
											date_of_birth,
											tag,
											codigo_postal,
											login_myhyundai,
											full_name,
											pioneiros_myhyundai,
											lead_source,
											nif,
											modo_de_contacto_preferencial,
											sexo,
											localidade,
											morada,
											concelho,
											description,
											last_activity_time,
											modified_time,
											data_de_validade_de_consentimento_hyundai,
											_fivetran_index,
											corporate;


ALTER TABLE workspace.sc_silver.contas_importador_pbs 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.contas_importador_pbs
DROP COLUMN IF EXISTS numero_de_cliente_dms,
											tipo_de_pedido,
											modo_de_contacto_preferencial,
											estado,
											quando_necessita_carro_novo,
											motivo_de_interesse,
											matricula,
											quando_prefere_ser_contactado,
											distrito,
											origem_registo,
											pais,
											telefone_da_empresa,
											row_names,
											conta_importador_name,
											conta_importador_owner_name,
											modified_time,
											last_activity_time,
											tag,
											motivo,
											localidade,
											morada,
											concelho,
											codigo_postal,
											formulario,
											nipc,
											e_mail_da_empresa,
											telephone_da_empresa,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.contas_pbs 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');


ALTER TABLE workspace.sc_silver.contas_pbs
DROP COLUMN IF EXISTS formulario,
											parent_conta,
											numero_de_cliente_dms,
											tipo_de_pedido,
											matricula,
											quando_necessita_carro_novo,
											quando_prefere_ser_contactado,
											motivo_de_interesse,
											description,
											data_criacao_da_conta,
											total_viaturas_hyundai,
											website,
											industry,
											pioneiros_myhyundai,
											login_myhyundai,
											cliente_hyundai,
											conta_type,
											motivo,
											id_lead_conversao,
											data_criacao_da_lead,
											agrupamento_performance_vendas,
											chave_agrupamento_performance_vendas,
											modo_de_contacto_preferencial,
											tipo_empresa,
											_fivetran_index,
											row_names,
											conta_name,
											nipc,
											tag,
											e_mail_da_empresa,
											telefone_da_empresa,
											morada,
											corporate;


ALTER TABLE workspace.sc_silver.contratos_financiamento 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.contratos_financiamento
DROP COLUMN IF EXISTS data_decisao,
											descricao_da_viatura,
											duracao,
											nif,
											nome,
											nome_empresa,
											nome_fornecedor,
											no_ct,
											tipo_de_aluguer,
											tylacode,
											data_seguro_auto,
											ca,
											co,
											gestao_de_combustivel,
											gestao_de_via_verde,
											km_contratados,
											manutencao,
											pneus,
											renda_com_iva,
											renda_sem_iva,
											viatura_de_substituicao_avarias,
											viatura_de_substituicao_furto,
											viatura_de_substituicao_revisoes,
											viatura_de_substituicao_sinistro,
											secondary_email,
											unsubscribed_mode,
											unsubscribed_time,
											valor_residual_da_viatura,
											tag,
											contacto_vinculado_id,
											data_criacao_da_lead,
											data_criacao_lead_financial_swap,
											telefone,
											condition,
											marca,
											row_names,
											modified_time,
											email_opt_out,
											last_activity_time,
											contratos_financiamento_owner_name,
											n_,
											auto_lead,
											vat_reclaimable,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.deals 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.deals
DROP COLUMN IF EXISTS forma_de_pagamento,
											descritivo_financiamento,
											financiamento,
											marca,
											isencao,
											mensalidade,
											prazo__meses_,
											taxa_de_juro,
											data_final_do_financiamento,
											modelo,
											aov,
											pronto_pagamento,
											hod,
											credito,
											ald,
											leasing,
											descricao_negocio,
											adiantamento,
											data_de_chegada_a_concessao,
											data_de_entrega_ao_cliente,
											cliente_hyundai,
											negocio_aprovado,
											data_real_de_entrega,
											row_names,
											tag,
											amount,
											expected_revenue,
											pioneiros_myhyundai,
											lead_source,
											login_myhyundai,
											aprovacao_do_pedido_de_apoio,
											type,
											deal_name,
											modified_time,
											last_activity_time,
											amount_tier,
											data_de_matricula,
											task_created,
											corporate,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.historico_de_servicos 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.historico_de_servicos
DROP COLUMN IF EXISTS servico_pos_venda,
											data_registo_pos_venda,
											numero_de_linhas,
											tag,
											email,
											secondary_email,
											unsubscribed_mode,
											unsubscribed_time,
											row_names,
											servico_pos_venda_owner_name,
											modified_time,
											last_activity_time,
											detalhe_spv,
											email_opt_out,
											spv_duplicado,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.leads_pbs 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.leads_pbs
DROP COLUMN IF EXISTS company,
											phone,
											secondary_email,
											tag,
											modo_de_contacto_preferencial,
											nif,
											nipc,
											matricula,
											sexo,
											data_de_nascimento,
											morada,
											localidade,
											concelho,
											data_e_hora_de_atribuicao,
											quando_prefere_ser_contactado,
											motivo_de_interesse,
											quando_necessita_carro_novo,
											import_manual,
											parque_empresa,
											inserido_por,
											cliente_hyundai,
											check_in,
											converted_account,
											last_name,
											row_names,
											email,
											mobile,
											telefone_empresa,
											e_mail_empresa,
											first_name,
											zip_code,
											description,
											salutation,
											motivo,
											hmod___hcreat,
											campaign_name,
											campaign_medium,
											campaign_term,
											campaign_content,
											campaignsource,
											con,
											caracterizacao,
											test_check1,
											test_check,
											link_centro_consentimento,
											industry,
											login_myhyundai,
											website,
											full_name,
											pontuacao,
											data_de_recolha_de_consentimento_hyundai,
											ccupdated,
											modified_time,
											last_activity_time,
											email_opt_out,
											tipo_de_lead,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.propostas_realizadas 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.propostas_realizadas
DROP COLUMN IF EXISTS isencao,
											ofertas,
											gestora_de_frota,
											contra_entrega_do_veiculo,
											adiantamento,
											data_de_assinatura_contrato,
											data_de_emissao_contrato,
											data_final_do_financiamento,
											matricula,
											sales_status,
											row_names,
											tax,
											discount,
											adjustments,
											resposta_do_importador,
											ofertas_de_campanha,
											estado_do_contrato,
											valid_until,
											nome_da_campanha,
											descricao_do_pedido_de_apoio,
											apoio_percentual,
											valor_campanhas_comerciais,
											sub_total,
											grand_total,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.viaturas 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.viaturas
DROP COLUMN IF EXISTS previsao_de_entrega,
											utilizador_da_viatura,
											comentario,
											estado_bluelink,
											motivo,
											battery,
											battery_action,
											battery_waring_level,
											dtc_1,
											dtc_10,
											dtc_2,
											dtc_3,
											dtc_4,
											dtc_5,
											dtc_6,
											dtc_7,
											dtc_8,
											dtc_9,
											dtc_date,
											dtc_status,
											map_sw_update_available,
											map_sw_version,
											mileage_unit,
											sent_date,
											soc____,
											sold,
											tms_start_dt,
											eliminar_duplicado,
											description_dtc_5,
											secondary_email,
											description_dtc_1,
											description_dtc_10,
											description_dtc_4,
											n__da_fatura,
											description_dtc_7,
											email,
											preco_unit_venda,
											description_dtc_6,
											n__dav,
											canal_de_venda,
											financeira_da_viatura,
											description_dtc_8,
											description_dtc_3,
											unsubscribed_time,
											dealer_name,
											description_dtc_9,
											dealer_code,
											origem_viatura,
											cod_postal_concessao,
											description_dtc_2,
											endereco_concessao,
											unsubscribed_mode,
											tem_contrato_de_manutencao,
											tag,
											extensao_de_garantia,
											prov_status,
											model_year,
											engine_type,
											country,
											no,
											model,
											row_names,
											modified_time,
											last_activity_time,
											extensao_promocional,
											check_test,
											_fivetran_index,
											gwms_verificado,
											wltp_co2,
											email_opt_out;


ALTER TABLE workspace.sc_silver.viaturas_demo 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.viaturas_demo
DROP COLUMN IF EXISTS comentario,
											data_de_venda,
											preco_base,
											email,
											pintura,
											secondary_email,
											unsubscribed_mode,
											iva,
											isv,
											unsubscribed_time,
											motivo,
											sgpu,
											tag,
											origem_registo,
											row_names,
											email_opt_out,
											_fivetran_index;


ALTER TABLE workspace.sc_silver.campanha_vouchers 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE workspace.sc_silver.campanha_vouchers
DROP COLUMN IF EXISTS email,
											unsubscribed_time,
											tag,
											secondary_email,
											unsubscribed_mode,
											row_names,
											email_opt_out,
											last_activity_time,
											modified_time,
											_fivetran_index;
